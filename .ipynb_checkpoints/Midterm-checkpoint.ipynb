# %% [markdown]
# # Q1. 畫出 Diamond Shape

# %%
import ffn
# %matplotlib inline
import numpy as np
import pandas as pd
import pandas_datareader.data as web
from datetime import datetime
import pickle
import talib
from talib import MA_Type
import requests
from io import StringIO

# %%
# 讀出預先下載好的股價資料
with open('stockdata', 'rb') as f:
    data = pickle.load(file=f)

# %%
def pyramid(n):
    for i in range(n):
        print(" "*(n-i) + "*"*(2*i+1))

# %%
def pyramid2(n):
    for i in range(n):
        print(" "*(i+2) + "*"*(2*(n-i-1)-1))

# %%
def Diamond (n):
    for i in range(n):
        print(pyramid(n) + pyramid2(n))

# %%
Diamond (10)
# Out:
#           *
#          ***
#         *****
#        *******
#       *********
#      ***********
#     *************
#    ***************
#   *****************
#  *******************
#   *****************
#    ***************
#     *************
#      ***********
#       *********
#        *******
#         *****
#          ***
#           *
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-cec87a105304> in <module>()
# ----> 1 Diamond (10)
#
# <ipython-input-31-cea0d6652db8> in Diamond(n)
#       1 def Diamond (n):
#       2     for i in range(n):
# ----> 3         print(pyramid(n) + pyramid2(n))
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'NoneType'

# %% [markdown]
# # Q2. 刪除重複性資料

# %%
with open('symbols01.txt') as f:
    symbols_01 = f.read().splitlines()
set_01 = set(symbols_01)

# %%
with open('symbols02.txt') as f:
    symbols_02 = f.read().splitlines()
set_02 = set(symbols_02)

# %%
symbols_03 = set_01 or set_02

# %%
with open('symbols_03.txt', 'w') as f:
    for symbol in symbols_03:
        f.write(symbol.strip().upper() + "\n")

# %% [markdown]
# # Q3. 下載台灣上市公司基本資料

# %%
r = requests.get("http://dts.twse.com.tw/opendata/t187ap03_L.csv")

# %%
r.encoding = 'big5'
companydatalist = r.text.split("\r\n")

# %%
companydatalist = pd.read_csv(StringIO(r.text),skiprows = 1)

# %%
companydatalist.head()
# Out:
#             公司代號  公司名稱                     產業別          住址 營利事業統一編號  董事長  總經理  \
# 1101  台灣水泥股份有限公司  水泥工業           台北市中山北路2段113號  11913502.0      張安平  李鐘培  黃健強
# 1102  亞洲水泥股份有限公司  水泥工業  台北市大安區敦化南路2段207號30、31樓   3244509.0      徐旭東  李坤炎  周維崑
# 1103  嘉新水泥股份有限公司  水泥工業            台北市中山北路2段96號  11892801.0      張剛綸  祁士鉅  王立心
# 1104  環球水泥股份有限公司  水泥工業        台北市南京東路二段125號10樓   7568009.0      侯博義  侯博義  楊宗仁
# 1108  幸福水泥股份有限公司  水泥工業           台北市松江路237號15樓  40601248.0      陳兩傳  陳兩傳  溫秀菊
#
#          發言人 發言人職稱          代理發言人 ...  特別股         編制財務報表類型         股票過戶機構  \
# 1101  資深副總經理   蔡立文  (02)2531-7099 ...  1.0      中國信託商業銀行代理部       66365566
# 1102    副總經理   吳玲綾   02-2733-8000 ...  1.0       亞東證券股份有限公司   02-2361-8608
# 1103  執行副總經理   余曉芸  (02)2551-5211 ...  1.0  群益金鼎證券股份有限公司股代部  (02)2702-3999
# 1104      經理   詹志鴻    02-25077801 ...  1.0  凱基證券股份有限公司股務代理部    02-23892999
# 1108   財務部經理   陳一誠       25092188 ...  1.0        永豐金證券股務代理      2381-6288
#
#                     過戶電話          過戶地址  \
# 2016-02-09  3604300
# 2016-02-10  2638000
# 2016-02-11  3024000
# 2016-02-12  2141400
# ...             ...
# 2017-10-24  1212200
# 2017-10-25  1211300
# 2017-10-26  2042100
# 2017-10-27  5167700
# 2017-10-30  2085100
# 2017-10-31  1330700
# 2017-11-01  1373400
# 2017-11-02  1049000
# 2017-11-03  1076400
# 2017-11-06  1125200
# 2017-11-07  1112300
# 2017-11-08  1088700
# 2017-11-09  1245200
# 2017-11-10   720000
# 2017-11-13   885800
# 2017-11-14   959200
# 2017-11-15   854000
# 2017-11-16  1129700
# 2017-11-17  1397100
# 2017-11-20   953500
# 2017-11-21  1097000
# 2017-11-22   746300
# 2017-11-24   537000
# 2017-11-27  1307900
# 2017-11-28  1424400
# 2017-11-29  2459400
# 2017-11-30  1724000
# 2017-12-01  1909600
# 2017-12-04  1906400
# 2017-12-05  2067318
#
# [487 rows x 6 columns]

# %%
df['26 ema'] = pd.ewma(df['Adj Close'], span=26)
df['12 ema'] = pd.ewma(df['Adj Close'], span=12)
df['DIF'] = (df['12 ema'] - df['26 ema'])
# Out:
# C:\Users\ROSE\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: pd.ewm_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.ewm(span=26,min_periods=0,adjust=True,ignore_na=False).mean()
#   """Entry point for launching an IPython kernel.
# C:\Users\ROSE\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pd.ewm_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.ewm(span=12,min_periods=0,adjust=True,ignore_na=False).mean()

# %%
df.plot(y= ['DIF'], title='DIF')

# %%
df['MACD'] = pd.ewma(df['DIF'], span=18)
# Out:
# C:\Users\ROSE\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: pd.ewm_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.ewm(span=18,min_periods=0,adjust=True,ignore_na=False).mean()
#   """Entry point for launching an IPython kernel.

# %%
df.plot(y= ['MACD'], title='MACD')

# %% [markdown]
# # Q5. 策略回測

# %%
# 計算 MaxDD
def DrawDownAnalysis(cumRet):
    dd_series = ffn.core.to_drawdown_series(cumRet)
    dd_details = ffn.core.drawdown_details(dd_series)
    return dd_details['drawdown'].min(), dd_details['days'].max()

# %%
# 利用策略產生的持有部位資訊，計算底下四個指標來判斷投資績效
# sharpe ratio: 判斷報酬的好壞跟穩定度，數值越大越好
# maxdd: maximum drawdown, 最糟糕的狀況會賠幾 %
# maxddd: maximum drawdown duration, 低於上一次最高報酬的天數
# cumRet[-1]: 最後賺的 % 數

def indicators(df):
    dailyRet = df['Close'].pct_change()
    excessRet = (dailyRet - 0.04/252)[df['positions'] == 1]
    SharpeRatio = np.sqrt(252.0)*np.mean(excessRet)/np.std(excessRet)
    
    cumRet = np.cumprod(1+excessRet)
    
    maxdd, maxddd = DrawDownAnalysis(cumRet)
    
    return SharpeRatio, maxdd, maxddd, cumRet[-1]

# %%
# 這是我們的策略的部分
# 主要只是要算出進出的訊號 signals 跟何時持有部位 positions
# 底下是一個突破系統的範例

def Breakout_strategy(df):
    # Donchian Channel
    df['20d_high'] = np.round(pd.Series.rolling(df['Close'], window=20).max(), 2)
    df['10d_low'] = np.round(pd.Series.rolling(df['Close'], window=10).min(), 2)

    has_position = False
    df['signals'] = 0
    for t in range(2, df['signals'].size):
        if df['Close'][t] > df['20d_high'][t-1]:
            if not has_position:
                df.loc[df.index[t], 'signals'] = 1
                has_position = True
        elif df['Close'][t] < df['10d_low'][t-1]:
            if has_position:
                df.loc[df.index[t], 'signals'] = -1
                has_position = False

    df['positions'] = df['signals'].cumsum().shift()
    return df

# %%
def RSI_7030_strategy(df):
    df['RSI'] = talib.RSI(df['Close'].values)
    
    has_position = False
    df['signals'] = 0
    for t in range(2, df['signals'].size):
        if df['RSI'][t-1] < 30:
            if not has_position:
                df.loc[df.index[t], 'signals'] = 1
                has_position = True
        elif df['RSI'][t-1] > 70:
            if has_position:
                df.loc[df.index[t], 'signals'] = -1
                has_position = False

    df['positions'] = df['signals'].cumsum().shift()
    return df

# %%
def BBands_strategy(df):
    df['UBB'], df['MBB'], df['LBB'] = talib.BBANDS(df['Close'].values, matype=MA_Type.T3)

    has_position = False
    df['signals'] = 0
    for t in range(2, df['signals'].size):
        if df['Close'][t] < df['LBB'][t-1]:
            if not has_position:
                df.loc[df.index[t], 'signals'] = 1
                has_position = True
        elif df['Close'][t] > df['UBB'][t-1]:
            if has_position:
                df.loc[df.index[t], 'signals'] = -1
                has_position = False

    df['positions'] = df['signals'].cumsum().shift()
    return df

# %%
# 定義你的策略
#當快線(DIF) 向上突破 慢線(MACD)。→買進訊號
#快線(DIF) 向下跌破 慢線(MACD)。→賣出訊號

def M064030032_strategy(df):
    df['26 ema'] = pd.ewma(df['Adj Close'], span=26)
    df['12 ema'] = pd.ewma(df['Adj Close'], span=12)
    df['DIF'] = (df['12 ema'] - df['26 ema'])
    df['MACD'] = pd.ewma(df['DIF'], span=18)
    
    has_position = False
    df['signals'] = 0
    for t in range(2, df['signals'].size):
        if df['DIF'][t] > df['MACD'][t-1]:
            if not has_position:
                df.loc[df.index[t], 'signals'] = 1
                has_position = True
        elif df['MACD'][t] > df['DIF'][t-1]:
            if has_position:
                df.loc[df.index[t], 'signals'] = -1
                has_position = False

    df['positions'] = df['signals'].cumsum().shift()
    return df

# %%
M064030032_strategy(df)
# Out:
# C:\Users\ROSE\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: pd.ewm_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.ewm(span=26,min_periods=0,adjust=True,ignore_na=False).mean()
#
# C:\Users\ROSE\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: FutureWarning: pd.ewm_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.ewm(span=12,min_periods=0,adjust=True,ignore_na=False).mean()
#   import sys
# C:\Users\ROSE\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: pd.ewm_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.ewm(span=18,min_periods=0,adjust=True,ignore_na=False).mean()
#   if __name__ == '__main__':
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2015-12-31   769.500000   769.500000   758.340027   758.880005   758.880005
# 2016-01-04   743.000000   744.059998   731.257996   741.840027   741.840027
# 2016-01-05   746.450012   752.000000   738.640015   742.580017   742.580017
# 2016-01-06   730.000000   747.179993   728.919983   743.619995   743.619995
# 2016-01-07   730.309998   738.500000   719.059998   726.390015   726.390015
# 2016-01-08   731.450012   733.229980   713.000000   714.469971   714.469971
# 2016-01-11   716.609985   718.854980   703.539978   716.030029   716.030029
# 2016-01-12   721.679993   728.750000   717.317017   726.070007   726.070007
# 2016-01-13   730.849976   734.739990   698.609985   700.559998   700.559998
# 2016-01-14   705.380005   721.924988   689.099976   714.719971   714.719971
# 2016-01-15   692.289978   706.739990   685.369995   694.450012   694.450012
# 2016-01-19   703.299988   709.979980   693.409973   701.789978   701.789978
# 2016-01-20   688.609985   706.849976   673.260010   698.450012   698.450012
    return strategy(df)

# %%
# 計算各支股票的回測結果
results = []

#strategies = [Breakout_strategy, RSI_7030_strategy, BBands_strategy, 學號_strategy]
strategies = [Breakout_strategy, RSI_7030_strategy, BBands_strategy, M064030032_strategy]

for symbol in data:
    for strategy in strategies:
        try:
            apply_strategy(strategy, data[symbol])
            if np.all(data[symbol]['signals']==0):
                print("Symbol:", symbol, "使用", strategy.__name__, "策略沒有出現買賣訊號。")
                continue
            SharpeRatio, maxdd, maxddd, finalRet = indicators(data[symbol])
            days = (data[symbol].index[-1] - data[symbol].index[0]).days
            results.append((SharpeRatio, maxdd, maxddd, finalRet, days,
                            data[symbol][data[symbol]['signals'] > 0]['signals'].sum(), symbol, strategy.__name__))
        except Exception as e:
            print("Error occurs at symbol:", symbol, "Strategy:", strategy.__name__, "==>", e.args)
# Out:
# C:\Users\ROSE\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: pd.ewm_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.ewm(span=26,min_periods=0,adjust=True,ignore_na=False).mean()
#
# C:\Users\ROSE\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: FutureWarning: pd.ewm_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.ewm(span=12,min_periods=0,adjust=True,ignore_na=False).mean()
#   import sys
# C:\Users\ROSE\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: pd.ewm_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.ewm(span=18,min_periods=0,adjust=True,ignore_na=False).mean()
#   if __name__ == '__main__':

# %%
results_df = pd.DataFrame(results, columns=['sharpe','MaxDrawDown','MaxDrawDownDuration','returns', 
                                            'days', 'entries','symbol','strategy'])

# %%
results_df.head()
# Out:
#      sharpe  MaxDrawDown  MaxDrawDownDuration   returns  days  entries symbol  \
# 0  0.131503    -0.208296                  281  0.995734   705       11   TICC
# 1  0.395515    -0.244817                  482  1.077756   705        2   TICC
# 2  0.102787    -0.231763                  426  0.984521   705       20   TICC
# 3  0.250482    -0.226466                  281  1.033057   705       15   TICC
# 4  1.365570    -0.361485                  299  1.631388   705       12   TWIN
#
#               strategy
# 0    Breakout_strategy
# 1    RSI_7030_strategy
# 2      BBands_strategy
# 3  M064030032_strategy
# 4    Breakout_strategy

# %%
results_df.sort_values('MaxDrawDown',ascending=False).head()
# Out:
#        sharpe  MaxDrawDown  MaxDrawDownDuration   returns  days  entries  \
# 73   6.306176    -0.003654                  122  1.028222   473        3
# 17  10.243474    -0.006251                    3  1.132402   705        1
# 74   2.038551    -0.013673                  119  1.060527   473       16
# 66   1.085572    -0.023454                  135  1.049505   384       12
# 36   3.040178    -0.023844                   58  1.073352   203        3
#
#    symbol           strategy
# 73    LCA  RSI_7030_strategy
# 17   GOOG  RSI_7030_strategy
# 74    LCA    BBands_strategy
# 66   SCAC    BBands_strategy
# 36   CSML  Breakout_strategy

# %%
results_df.sort_values('returns',ascending=False).head()
# Out:
#       sharpe  MaxDrawDown  MaxDrawDownDuration   returns  days  entries  \
# 9   2.013777    -0.219296                  167  2.477803   705        4
# 14  2.062962    -0.286661                  113  2.422460   705       22
# 78  2.136744    -0.454342                  191  2.400221   705       21
# 5   2.424484    -0.169115                  115  2.151881   705        3
# 27  2.157509    -0.199261                  165  1.891485   705       13
#
#    symbol             strategy
# 9    AMOT    RSI_7030_strategy
# 14   CDZI      BBands_strategy
# 78   BBGI      BBands_strategy
# 5    TWIN    RSI_7030_strategy
# 27   RICK  M064030032_strategy
